# %%
pip install feature_engine
# Out:
# Requirement already satisfied: feature_engine in c:\users\asus\anaconda3\lib\site-packages (1.6.2)
# Requirement already satisfied: statsmodels>=0.11.1 in c:\users\asus\anaconda3\lib\site-packages (from feature_engine) (0.13.2)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\asus\anaconda3\lib\site-packages (from feature_engine) (1.23.5)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from feature_engine) (1.0.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\asus\anaconda3\lib\site-packages (from feature_engine) (1.9.1)
# Requirement already satisfied: pandas>=1.0.3 in c:\users\asus\anaconda3\lib\site-packages (from feature_engine) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.0.3->feature_engine) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.0.3->feature_engine) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->feature_engine) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->feature_engine) (1.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\asus\anaconda3\lib\site-packages (from statsmodels>=0.11.1->feature_engine) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\asus\anaconda3\lib\site-packages (from statsmodels>=0.11.1->feature_engine) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asus\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.11.1->feature_engine) (3.0.9)
# Requirement already satisfied: six in c:\users\asus\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.11.1->feature_engine) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from feature_engine.datetime import DatetimeFeatures
from feature_engine.imputation import DropMissingData
from feature_engine.creation import CyclicalFeatures
from feature_engine.selection import DropFeatures
from feature_engine.timeseries.forecasting import (LagFeatures,WindowFeatures,)
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.multioutput import MultiOutputRegressor
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('AirQualityUCI.csv', sep=';', parse_dates=[['Date', 'Time']]).iloc[:, :-2]
data.dropna(inplace=True)

# %%
new_names = [
    'Date_Time',
    'CO_true',
    'CO_sensor',
    'NMHC_true',
    'C6H6_true',
    'NMHC_sensor',
    'NOX_true',
    'NOX_sensor',
    'NO2_true',
    'NO2_sensor',
    'O3_sensor',
    'T',
    'RH',
    'AH',    
]

# %%
data.columns=new_names

# %%
data.head()
# Out:
#              Date_Time CO_true  CO_sensor  NMHC_true C6H6_true  NMHC_sensor  \
# 0  10/03/2004 18.00.00     2,6     1360.0      150.0      11,9       1046.0
# 1  10/03/2004 19.00.00       2     1292.0      112.0       9,4        955.0
# 2  10/03/2004 20.00.00     2,2     1402.0       88.0       9,0        939.0
# 3  10/03/2004 21.00.00     2,2     1376.0       80.0       9,2        948.0
# 4  10/03/2004 22.00.00     1,6     1272.0       51.0       6,5        836.0
#
#    NOX_true  NOX_sensor  NO2_true  NO2_sensor  O3_sensor     T    RH      AH
# 0     166.0      1056.0     113.0      1692.0     1268.0  13,6  48,9  0,7578
# 1     103.0      1174.0      92.0      1559.0      972.0  13,3  47,7  0,7255
# 2     131.0      1140.0     114.0      1555.0     1074.0  11,9  54,0  0,7502
# 3     172.0      1092.0     122.0      1584.0     1203.0  11,0  60,0  0,7867
# 4     131.0      1205.0     116.0      1490.0     1110.0  11,2  59,6  0,7888

# %%
predictors=data.loc[1:]

# %%
predictors
# Out:
#                 Date_Time CO_true  CO_sensor  NMHC_true C6H6_true  \
# 1     10/03/2004 19.00.00       2     1292.0      112.0       9,4
# 2     10/03/2004 20.00.00     2,2     1402.0       88.0       9,0
# 3     10/03/2004 21.00.00     2,2     1376.0       80.0       9,2
# 4     10/03/2004 22.00.00     1,6     1272.0       51.0       6,5
# 5     10/03/2004 23.00.00     1,2     1197.0       38.0       4,7
# ...                   ...     ...        ...        ...       ...
# 9352  04/04/2005 10.00.00     3,1     1314.0     -200.0      13,5
# 9353  04/04/2005 11.00.00     2,4     1163.0     -200.0      11,4
# 9354  04/04/2005 12.00.00     2,4     1142.0     -200.0      12,4
# 9355  04/04/2005 13.00.00     2,1     1003.0     -200.0       9,5
# 9356  04/04/2005 14.00.00     2,2     1071.0     -200.0      11,9
#
#       NMHC_sensor  NOX_true  NOX_sensor  NO2_true  NO2_sensor  O3_sensor  \
# 1           955.0     103.0      1174.0      92.0      1559.0      972.0
# 2           939.0     131.0      1140.0     114.0      1555.0     1074.0
# 3           948.0     172.0      1092.0     122.0      1584.0     1203.0
# 4           836.0     131.0      1205.0     116.0      1490.0     1110.0
# 5           750.0      89.0      1337.0      96.0      1393.0      949.0
# ...           ...       ...         ...       ...         ...        ...
# 9352       1101.0     472.0       539.0     190.0      1374.0     1729.0
# 9353       1027.0     353.0       604.0     179.0      1264.0     1269.0
# 9354       1063.0     293.0       603.0     175.0      1241.0     1092.0
# 9355        961.0     235.0       702.0     156.0      1041.0      770.0
# 9356       1047.0     265.0       654.0     168.0      1129.0      816.0
#
#          T    RH      AH
# 1     13,3  47,7  0,7255
# 2     11,9  54,0  0,7502
# 3     11,0  60,0  0,7867
# 4     11,2  59,6  0,7888
# 5     11,2  59,2  0,7848
# ...    ...   ...     ...
# 9352  21,9  29,3  0,7568
# 9353  24,3  23,7  0,7119
# 9354  26,9  18,3  0,6406
# 9355  28,3  13,5  0,5139
# 9356  28,5  13,1  0,5028
#
# [9356 rows x 14 columns]

# %%
data['Date_Time'] = data['Date_Time'].str.replace('.', ':', regex=False)

data['Date_Time'] = pd.to_datetime(data['Date_Time'])
# use dayfirst=True parameter if format is dd/mm/yyyy HH:mm:ss Eg: pd.to_datetime(data['Date_Time'], dayfirst=True)

data.head()
# Out:
#             Date_Time CO_true  CO_sensor  NMHC_true C6H6_true  NMHC_sensor  \
# 0 2004-10-03 18:00:00     2,6     1360.0      150.0      11,9       1046.0
# 1 2004-10-03 19:00:00       2     1292.0      112.0       9,4        955.0
# 2 2004-10-03 20:00:00     2,2     1402.0       88.0       9,0        939.0
# 3 2004-10-03 21:00:00     2,2     1376.0       80.0       9,2        948.0
# 4 2004-10-03 22:00:00     1,6     1272.0       51.0       6,5        836.0
#
#    NOX_true  NOX_sensor  NO2_true  NO2_sensor  O3_sensor     T    RH      AH
# 0     166.0      1056.0     113.0      1692.0     1268.0  13,6  48,9  0,7578
# 1     103.0      1174.0      92.0      1559.0      972.0  13,3  47,7  0,7255
# 2     131.0      1140.0     114.0      1555.0     1074.0  11,9  54,0  0,7502
# 3     172.0      1092.0     122.0      1584.0     1203.0  11,0  60,0  0,7867
# 4     131.0      1205.0     116.0      1490.0     1110.0  11,2  59,6  0,7888

# %%
for var in predictors:
    if data[var].dtype=="O":
        data[var]=data[var].str.replace(',','.')
        data[var]=pd.to_numeric(data[var])

# %%
data=data.loc[:,["Date_Time", "CO_sensor", "RH"]]

# %%
data.head()
# Out:
#             Date_Time  CO_sensor    RH
# 0 2004-10-03 18:00:00     1360.0  48.9
# 1 2004-10-03 19:00:00     1292.0  47.7
# 2 2004-10-03 20:00:00     1402.0  54.0
# 3 2004-10-03 21:00:00     1376.0  60.0
# 4 2004-10-03 22:00:00     1272.0  59.6

# %%
data.set_index('Date_Time',inplace=True)
data.head()
# Out:
#                      CO_sensor    RH
# Date_Time
# 2004-10-03 18:00:00     1360.0  48.9
# 2004-10-03 19:00:00     1292.0  47.7
# 2004-10-03 20:00:00     1402.0  54.0
# 2004-10-03 21:00:00     1376.0  60.0
# 2004-10-03 22:00:00     1272.0  59.6

# %%
data1=data.copy()

# %%
data.sort_index(inplace=True)
data.head()
# Out:
#                      CO_sensor    RH
# Date_Time
# 2004-01-04 00:00:00     1143.0  61.6
# 2004-01-04 01:00:00     1044.0  63.9
# 2004-01-04 02:00:00     1034.0  67.2
# 2004-01-04 03:00:00      956.0  73.1
# 2004-01-04 04:00:00      909.0  66.6

# %%
# Reducing data size.
data = data.loc["2004-04-01":"2005-04-30"]

# %%
data.head()
# Out:
#                      CO_sensor    RH
# Date_Time
# 2004-04-04 00:00:00     1224.0  56.5
# 2004-04-04 01:00:00     1215.0  59.2
# 2004-04-04 02:00:00     1115.0  62.4
# 2004-04-04 03:00:00     1124.0  65.0
# 2004-04-04 04:00:00     1028.0  65.3

# %%
data=data.loc[(data['CO_sensor']>=0)& data['RH']>0] # removing outliers

# %% [markdown]
# # DateTime Features using FeatureEngine

# %%
dtf=DatetimeFeatures(
variables='index',
features_to_extract=[
    "month",
    "week",
    "day_of_week",
    "day_of_month",
    'hour',
    "weekend"
],
)
data=dtf.fit_transform(data)# extracting the date time variable
data.head()
# Out:
#                      CO_sensor    RH  month  week  day_of_week  day_of_month  \
# Date_Time
# 2004-04-04 00:00:00     1224.0  56.5      4    14            6             4
# 2004-04-04 01:00:00     1215.0  59.2      4    14            6             4
# 2004-04-04 02:00:00     1115.0  62.4      4    14            6             4
# 2004-04-04 03:00:00     1124.0  65.0      4    14            6             4
# 2004-04-04 04:00:00     1028.0  65.3      4    14            6             4
#
#                      hour  weekend
# Date_Time
# 2004-04-04 00:00:00     0        1
# 2004-04-04 01:00:00     1        1
# 2004-04-04 02:00:00     2        1
# 2004-04-04 03:00:00     3        1
# 2004-04-04 04:00:00     4        1

# %% [markdown]
# # Lag Features

# %%
lagfeature=LagFeatures(
    variables=["CO_sensor","RH"],
    freq=["1H","24H"], # moves 1 hour and 24 hour fordward
    missing_values="ignore"
)
data=lagfeature.fit_transform(data)#adding lag feature

# %%
data.head()
# Out:
#                      CO_sensor    RH  month  week  day_of_week  day_of_month  \
# Date_Time
# 2004-04-04 00:00:00     1224.0  56.5      4    14            6             4
# 2004-04-04 01:00:00     1215.0  59.2      4    14            6             4
# 2004-04-04 02:00:00     1115.0  62.4      4    14            6             4
# 2004-04-04 03:00:00     1124.0  65.0      4    14            6             4
# 2004-04-04 04:00:00     1028.0  65.3      4    14            6             4
#
#                      hour  weekend  CO_sensor_lag_1H  RH_lag_1H  \
# Date_Time
# 2004-04-04 00:00:00     0        1               NaN        NaN
# 2004-04-04 01:00:00     1        1            1224.0       56.5
# 2004-04-04 02:00:00     2        1            1215.0       59.2
# 2004-04-04 03:00:00     3        1            1115.0       62.4
# 2004-04-04 04:00:00     4        1            1124.0       65.0
#
#                      CO_sensor_lag_24H  RH_lag_24H
# Date_Time
# 2004-04-04 00:00:00                NaN         NaN
# 2004-04-04 01:00:00                NaN         NaN
# 2004-04-04 02:00:00                NaN         NaN
# 2004-04-04 03:00:00                NaN         NaN
# 2004-04-04 04:00:00                NaN         NaN

# %% [markdown]
# # Window feature

# %%
windowfeature=WindowFeatures(
variables=["CO_sensor","RH"],
window="3H",
freq="1H",
missing_values="ignore"
)
data=windowfeature.fit_transform(data)

# %%
data.head()
# Out:
#                      CO_sensor    RH  month  week  day_of_week  day_of_month  \
# Date_Time
# 2004-04-04 00:00:00     1224.0  56.5      4    14            6             4
# 2004-04-04 01:00:00     1215.0  59.2      4    14            6             4
# 2004-04-04 02:00:00     1115.0  62.4      4    14            6             4
# 2004-04-04 03:00:00     1124.0  65.0      4    14            6             4
# 2004-04-04 04:00:00     1028.0  65.3      4    14            6             4
#
#                      hour  weekend  CO_sensor_lag_1H  RH_lag_1H  \
# Date_Time
# 2004-04-04 00:00:00     0        1               NaN        NaN
# 2004-04-04 01:00:00     1        1            1224.0       56.5
# 2004-04-04 02:00:00     2        1            1215.0       59.2
# 2004-04-04 03:00:00     3        1            1115.0       62.4
# 2004-04-04 04:00:00     4        1            1124.0       65.0
#
#                      CO_sensor_lag_24H  RH_lag_24H  CO_sensor_window_3H_mean  \
# Date_Time
# 2004-04-04 00:00:00                NaN         NaN                       NaN
# 2004-04-04 01:00:00                NaN         NaN               1224.000000
# 2004-04-04 02:00:00                NaN         NaN               1219.500000
# 2004-04-04 03:00:00                NaN         NaN               1184.666667
# 2004-04-04 04:00:00                NaN         NaN               1151.333333
#
#                      RH_window_3H_mean
# Date_Time
# 2004-04-04 00:00:00                NaN
# 2004-04-04 01:00:00          56.500000
# 2004-04-04 02:00:00          57.850000
# 2004-04-04 03:00:00          59.366667
# 2004-04-04 04:00:00          62.200000

# %% [markdown]
# # Perodic Feature

# %%
cyclicalfeature=CyclicalFeatures(
    variables=["CO_sensor","RH"],
    drop_original=False
)
data=cyclicalfeature.fit_transform(data)

# %%
data.head()
# Out:
#                      CO_sensor    RH  month  week  day_of_week  day_of_month  \
# Date_Time
# 2004-04-04 00:00:00     1224.0  56.5      4    14            6             4
# 2004-04-04 01:00:00     1215.0  59.2      4    14            6             4
# 2004-04-04 02:00:00     1115.0  62.4      4    14            6             4
# 2004-04-04 03:00:00     1124.0  65.0      4    14            6             4
# 2004-04-04 04:00:00     1028.0  65.3      4    14            6             4
#
#                      hour  weekend  CO_sensor_lag_1H  RH_lag_1H  \
# Date_Time
# 2004-04-04 00:00:00     0        1               NaN        NaN
# 2004-04-04 01:00:00     1        1            1224.0       56.5
# 2004-04-04 02:00:00     2        1            1215.0       59.2
# 2004-04-04 03:00:00     3        1            1115.0       62.4
# 2004-04-04 04:00:00     4        1            1124.0       65.0
#
#                      CO_sensor_lag_24H  RH_lag_24H  CO_sensor_window_3H_mean  \
# Date_Time
# 2004-04-04 00:00:00                NaN         NaN                       NaN
# 2004-04-04 01:00:00                NaN         NaN               1224.000000
# 2004-04-04 02:00:00                NaN         NaN               1219.500000
# 2004-04-04 03:00:00                NaN         NaN               1184.666667
# 2004-04-04 04:00:00                NaN         NaN               1151.333333
#
#                      RH_window_3H_mean  CO_sensor_sin  CO_sensor_cos  \
# Date_Time
# 2004-04-04 00:00:00                NaN      -0.635300      -0.772266
# 2004-04-04 01:00:00          56.500000      -0.613303      -0.789848
# 2004-04-04 02:00:00          57.850000      -0.340386      -0.940286
# 2004-04-04 03:00:00          59.366667      -0.366728      -0.930328
# 2004-04-04 04:00:00          62.200000      -0.075027      -0.997181
#
#                        RH_sin    RH_cos
# Date_Time
# 2004-04-04 00:00:00 -0.758274 -0.651936
# 2004-04-04 01:00:00 -0.868377 -0.495905
# 2004-04-04 02:00:00 -0.957612 -0.288060
# 2004-04-04 03:00:00 -0.994171 -0.107815
# 2004-04-04 04:00:00 -0.996237 -0.086666

# %% [markdown]
# # Missing values

# %%
data.isnull().sum()
# Out:
# CO_sensor                     0
# RH                            0
# month                         0
# week                          0
# day_of_week                   0
# day_of_month                  0
# hour                          0
# weekend                       0
# CO_sensor_lag_1H             27
# RH_lag_1H                    27
# CO_sensor_lag_24H           461
# RH_lag_24H                  461
# CO_sensor_window_3H_mean     27
# RH_window_3H_mean            27
# CO_sensor_sin                 0
# CO_sensor_cos                 0
# RH_sin                        0
# RH_cos                        0
# dtype: int64

# %%
#Droping the missing data
imputer=DropMissingData()
data=imputer.fit_transform(data)

# %%
#imputer=DropMissingData()

# %%
data.isnull().sum()
# Out:
# CO_sensor                   0
# RH                          0
# month                       0
# week                        0
# day_of_week                 0
# day_of_month                0
# hour                        0
# weekend                     0
# CO_sensor_lag_1H            0
# RH_lag_1H                   0
# CO_sensor_lag_24H           0
# RH_lag_24H                  0
# CO_sensor_window_3H_mean    0
# RH_window_3H_mean           0
# CO_sensor_sin               0
# CO_sensor_cos               0
# RH_sin                      0
# RH_cos                      0
# dtype: int64

# %% [markdown]
# Droping Orginal Time Series Data to avoid lookahead bais

# %%
data2=data.copy()

# %%
dropft=DropFeatures(features_to_drop=["CO_sensor","RH"])

# %%
#imputer=DropMissingData()

# %% [markdown]
# # Pipeline

# %% [markdown]
# Extracting all the features in one step using feature engine pipline

# %%
data=data1

# %%
data.head()
# Out:
#                      CO_sensor    RH
# Date_Time
# 2004-10-03 18:00:00     1360.0  48.9
# 2004-10-03 19:00:00     1292.0  47.7
# 2004-10-03 20:00:00     1402.0  54.0
# 2004-10-03 21:00:00     1376.0  60.0
# 2004-10-03 22:00:00     1272.0  59.6

# %%
pipe=Pipeline([
    ("datetime_feature",dtf),
    ("lagfeatue",lagfeature),
    ("windowfeature",windowfeature),
    ("Perodic",cyclicalfeature),
    ("dropna", imputer),
    ("drop_ts",dropft),
    
])

# %% [markdown]
# # Spliting the data into Train and Test sets

# %% [markdown]
# last month data is 4 of march 2005 but we need 24 hours pervious data to create the feature

# %%
data.head()
# Out:
#                      CO_sensor    RH
# Date_Time
# 2004-10-03 18:00:00     1360.0  48.9
# 2004-10-03 19:00:00     1292.0  47.7
# 2004-10-03 20:00:00     1402.0  54.0
# 2004-10-03 21:00:00     1376.0  60.0
# 2004-10-03 22:00:00     1272.0  59.6

# %%
# input data
X_train=data[data.index<"2005-03-04"]
X_test=data[data.index>=pd.Timestamp("2005-03-04")- pd.offsets.Hour(24)]

# %%
#target
Y_train=data[data.index<"2005-03-04"][["CO_sensor","RH"]]
Y_test=data[data.index>=pd.Timestamp("2005-03-04")- pd.offsets.Hour(24)][["CO_sensor","RH"]]

# %%
Y_train.head()
# Out:
#                      CO_sensor    RH
# Date_Time
# 2004-10-03 18:00:00     1360.0  48.9
# 2004-10-03 19:00:00     1292.0  47.7
# 2004-10-03 20:00:00     1402.0  54.0
# 2004-10-03 21:00:00     1376.0  60.0
# 2004-10-03 22:00:00     1272.0  59.6

# %% [markdown]
# # Training pipeline and model

# %%
# we will train the pipeline and create the features for the training set
X_train_1=pipe.fit_transform(X_train)

# %%
#Data with input features
X_train_1.head()
# Out:
#                      month  week  day_of_week  day_of_month  hour  weekend  \
# Date_Time
# 2004-01-05 00:00:00      1     2            0             5     0        0
# 2004-01-05 01:00:00      1     2            0             5     1        0
# 2004-01-05 02:00:00      1     2            0             5     2        0
# 2004-01-05 03:00:00      1     2            0             5     3        0
# 2004-01-05 04:00:00      1     2            0             5     4        0
#
#                      CO_sensor_lag_1H  RH_lag_1H  CO_sensor_lag_24H  \
# Date_Time
# 2004-01-05 00:00:00            1203.0       52.0             1143.0
# 2004-01-05 01:00:00            1425.0       66.8             1044.0
# 2004-01-05 02:00:00            1179.0       68.3             1034.0
# 2004-01-05 03:00:00            1047.0       70.2              956.0
# 2004-01-05 04:00:00            1009.0       73.1              909.0
#
#                      RH_lag_24H  CO_sensor_window_3H_mean  RH_window_3H_mean  \
# Date_Time
# 2004-01-05 00:00:00        61.6               1193.666667          48.000000
# 2004-01-05 01:00:00        63.9               1271.333333          55.600000
# 2004-01-05 02:00:00        67.2               1269.000000          62.366667
# 2004-01-05 03:00:00        73.1               1217.000000          68.433333
# 2004-01-05 04:00:00        66.6               1078.333333          70.533333
#
#                      CO_sensor_sin  CO_sensor_cos    RH_sin    RH_cos
# Date_Time
# 2004-01-05 00:00:00      -0.948161      -0.317791 -0.999810  0.019479
# 2004-01-05 01:00:00      -0.470378      -0.882465 -0.992106  0.125404
# 2004-01-05 02:00:00      -0.083064      -0.996544 -0.966307  0.257393
# 2004-01-05 03:00:00       0.033873      -0.999426 -0.893485  0.449092
# 2004-01-05 04:00:00       0.412356      -0.911023 -0.971558  0.236802

# %% [markdown]
# our transformer removed the observation with missing data so we need to remove those observation from target variable  as well

# %%
Y_train_1=Y_train.loc[X_train_1.index]

# %%
print(X_train_1.shape)
print(Y_train_1.shape)
# Out:
# (7878, 16)
# (7878, 2)

# %% [markdown]
# # lasso Regression

# %% [markdown]
# we need multiple regression as we need a prediction of CO concentration and prediction of RH

# %%
lasso=MultiOutputRegressor(Lasso(random_state=0))

# %%
lasso.fit(X_train_1,Y_train_1)
# Out:
# MultiOutputRegressor(estimator=Lasso(random_state=0))

# %% [markdown]
# # Forcasting 24 hour fordward fordward step by step

# %% [markdown]
# First we will obtain the 24 hours forcast in the 24 hours in the testset

# %%
#first hour of forcast
forcast_point=pd.Timestamp("2005-03-04")

#forcast horizon 24 hours ahead
forcast_end=forcast_point + pd.offsets.Hour(23)

# %%
forcast_point
# Out:
# Timestamp('2005-03-04 00:00:00')

# %%
forcast_end
# Out:
# Timestamp('2005-03-04 23:00:00')

# %%
# Time stamp for which we wanted to predict Carbon monixide concentration
index=pd.date_range(
start=forcast_point,
end=forcast_end,
freq="1H")

# Here we will be starting the forcasting from forcasting point upto forcast end during 1 hours of interval.

# %%
index
# Out:
# DatetimeIndex(['2005-03-04 00:00:00', '2005-03-04 01:00:00',
#                '2005-03-04 02:00:00', '2005-03-04 03:00:00',
#                '2005-03-04 04:00:00', '2005-03-04 05:00:00',
#                '2005-03-04 06:00:00', '2005-03-04 07:00:00',
#                '2005-03-04 08:00:00', '2005-03-04 09:00:00',
#                '2005-03-04 10:00:00', '2005-03-04 11:00:00',
#                '2005-03-04 12:00:00', '2005-03-04 13:00:00',
#                '2005-03-04 14:00:00', '2005-03-04 15:00:00',
#                '2005-03-04 16:00:00', '2005-03-04 17:00:00',
#                '2005-03-04 18:00:00', '2005-03-04 19:00:00',
#                '2005-03-04 20:00:00', '2005-03-04 21:00:00',
#                '2005-03-04 22:00:00', '2005-03-04 23:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
# forcasting horizon
f_horizon=pd.DataFrame(columns=["CO_sensor","RH"],index=index)
f_horizon
# Out:
#                     CO_sensor   RH
# 2005-03-04 00:00:00       NaN  NaN
# 2005-03-04 01:00:00       NaN  NaN
# 2005-03-04 02:00:00       NaN  NaN
# 2005-03-04 03:00:00       NaN  NaN
# 2005-03-04 04:00:00       NaN  NaN
# 2005-03-04 05:00:00       NaN  NaN
# 2005-03-04 06:00:00       NaN  NaN
# 2005-03-04 07:00:00       NaN  NaN
# 2005-03-04 08:00:00       NaN  NaN
# 2005-03-04 09:00:00       NaN  NaN
# 2005-03-04 10:00:00       NaN  NaN
# 2005-03-04 11:00:00       NaN  NaN
# 2005-03-04 12:00:00       NaN  NaN
# 2005-03-04 13:00:00       NaN  NaN
# 2005-03-04 14:00:00       NaN  NaN
# 2005-03-04 15:00:00       NaN  NaN
# 2005-03-04 16:00:00       NaN  NaN
# 2005-03-04 17:00:00       NaN  NaN
# 2005-03-04 18:00:00       NaN  NaN
# 2005-03-04 19:00:00       NaN  NaN
# 2005-03-04 20:00:00       NaN  NaN
# 2005-03-04 21:00:00       NaN  NaN
# 2005-03-04 22:00:00       NaN  NaN
# 2005-03-04 23:00:00       NaN  NaN

# %% [markdown]
# # Forcasting 1 hour fordward

# %%
# 24 hours before the first forcasting point
start_point=forcast_point-pd.offsets.Hour(24)
start_point
# Out:
# Timestamp('2005-03-03 00:00:00')

# %%
#input data for first prediction value
input_data=X_test[(X_test.index>= start_point)&(X_test.index<forcast_point)]
input_data.loc[forcast_point]=0 #puting nan value for forcasting point
input_data
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_5912\239146049.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   input_data.loc[forcast_point]=0 #puting nan value for forcasting point
#                      CO_sensor    RH
# Date_Time
# 2005-03-03 00:00:00     1047.0  41.7
# 2005-03-03 01:00:00     1030.0  43.3
# 2005-03-03 02:00:00      986.0  45.9
# 2005-03-03 03:00:00      992.0  49.7
# 2005-03-03 04:00:00     1076.0  56.3
# 2005-03-03 05:00:00     1104.0  67.9
# 2005-03-03 06:00:00     1160.0  74.1
# 2005-03-03 07:00:00     1217.0  75.6
# 2005-03-03 08:00:00     1457.0  72.4
# 2005-03-03 09:00:00     1337.0  50.2
# 2005-03-03 10:00:00     1111.0  39.4
# 2005-03-03 11:00:00     1165.0  75.9
# 2005-03-03 12:00:00     1129.0  78.6
# 2005-03-03 13:00:00     1092.0  69.2
# 2005-03-03 14:00:00     1096.0  66.0
# 2005-03-03 15:00:00     1108.0  70.1
# 2005-03-03 16:00:00     1124.0  72.1
# 2005-03-03 17:00:00     1216.0  75.7
# 2005-03-03 18:00:00     1437.0  80.4
# 2005-03-03 19:00:00     1473.0  82.4
# 2005-03-03 20:00:00     1396.0  84.0
# 2005-03-03 21:00:00     1285.0  83.6
# 2005-03-03 22:00:00     1206.0  82.5
# 2005-03-03 23:00:00     1179.0  82.0
# 2005-03-04 00:00:00        0.0   0.0

# %%
len(input_data)
# Out:
# 25

# %%
# test transformation
pipe.transform(input_data)
# Out:
#             month  week  day_of_week  day_of_month  hour  weekend  \
# Date_Time
# 2005-03-04      3     9            4             4     0        0
#
#             CO_sensor_lag_1H  RH_lag_1H  CO_sensor_lag_24H  RH_lag_24H  \
# Date_Time
# 2005-03-04            1179.0       82.0             1047.0        41.7
#
#             CO_sensor_window_3H_mean  RH_window_3H_mean  CO_sensor_sin  \
# Date_Time
# 2005-03-04               1223.333333               82.7            0.0
#
#             CO_sensor_cos  RH_sin  RH_cos
# Date_Time
# 2005-03-04            1.0     0.0     1.0

# %%
#first prediction
prediction=lasso.predict(pipe.transform(input_data))

# %%
prediction
# Out:
# array([[1208.07616546,   77.60414478]])

# %%
f_horizon.loc[forcast_point]=prediction

# %%
f_horizon
# Out:
#                        CO_sensor         RH
# 2005-03-04 00:00:00  1208.076165  77.604145
# 2005-03-04 01:00:00          NaN        NaN
# 2005-03-04 02:00:00          NaN        NaN
# 2005-03-04 03:00:00          NaN        NaN
# 2005-03-04 04:00:00          NaN        NaN
# 2005-03-04 05:00:00          NaN        NaN
# 2005-03-04 06:00:00          NaN        NaN
# 2005-03-04 07:00:00          NaN        NaN
# 2005-03-04 08:00:00          NaN        NaN
# 2005-03-04 09:00:00          NaN        NaN
# 2005-03-04 10:00:00          NaN        NaN
# 2005-03-04 11:00:00          NaN        NaN
# 2005-03-04 12:00:00          NaN        NaN
# 2005-03-04 13:00:00          NaN        NaN
# 2005-03-04 14:00:00          NaN        NaN
# 2005-03-04 15:00:00          NaN        NaN
# 2005-03-04 16:00:00          NaN        NaN
# 2005-03-04 17:00:00          NaN        NaN
# 2005-03-04 18:00:00          NaN        NaN
# 2005-03-04 19:00:00          NaN        NaN
# 2005-03-04 20:00:00          NaN        NaN
# 2005-03-04 21:00:00          NaN        NaN
# 2005-03-04 22:00:00          NaN        NaN
# 2005-03-04 23:00:00          NaN        NaN

# %% [markdown]
# # Forcasting 24 hours altogether

# %%
#crating the forcasting horizen
#first hour
forcast_point=pd.Timestamp("2005-03-04")
#forcasting horizen
forcast_end=forcast_point+pd.offsets.Hour(23)

# Time stamp for which we wanted to predict Carbon monixide concentration
index=pd.date_range(
start=forcast_point,
end=forcast_end,
freq="1H")

# the forecasting horizon
f_horizon = pd.DataFrame(columns=["CO_sensor", "RH"], index=index)
f_horizon
# Out:
#                     CO_sensor   RH
# 2005-03-04 00:00:00       NaN  NaN
# 2005-03-04 01:00:00       NaN  NaN
# 2005-03-04 02:00:00       NaN  NaN
# 2005-03-04 03:00:00       NaN  NaN
# 2005-03-04 04:00:00       NaN  NaN
# 2005-03-04 05:00:00       NaN  NaN
# 2005-03-04 06:00:00       NaN  NaN
# 2005-03-04 07:00:00       NaN  NaN
# 2005-03-04 08:00:00       NaN  NaN
# 2005-03-04 09:00:00       NaN  NaN
# 2005-03-04 10:00:00       NaN  NaN
# 2005-03-04 11:00:00       NaN  NaN
# 2005-03-04 12:00:00       NaN  NaN
# 2005-03-04 13:00:00       NaN  NaN
# 2005-03-04 14:00:00       NaN  NaN
# 2005-03-04 15:00:00       NaN  NaN
# 2005-03-04 16:00:00       NaN  NaN
# 2005-03-04 17:00:00       NaN  NaN
# 2005-03-04 18:00:00       NaN  NaN
# 2005-03-04 19:00:00       NaN  NaN
# 2005-03-04 20:00:00       NaN  NaN
# 2005-03-04 21:00:00       NaN  NaN
# 2005-03-04 22:00:00       NaN  NaN
# 2005-03-04 23:00:00       NaN  NaN

# %%
# 24 hours before the first forcasting point
start_point=forcast_point-pd.offsets.Hour(24)
start_point
# Out:
# Timestamp('2005-03-03 00:00:00')

# %%
#input data for first prediction value
input_data=X_test[(X_test.index>= start_point)&(X_test.index<forcast_point)]
input_data.loc[forcast_point]=0 #puting nan value for forcasting point
input_data
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_5912\239146049.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   input_data.loc[forcast_point]=0 #puting nan value for forcasting point
#                      CO_sensor    RH
# Date_Time
# 2005-03-03 00:00:00     1047.0  41.7
# 2005-03-03 01:00:00     1030.0  43.3
# 2005-03-03 02:00:00      986.0  45.9
# 2005-03-03 03:00:00      992.0  49.7
# 2005-03-03 04:00:00     1076.0  56.3
# 2005-03-03 05:00:00     1104.0  67.9
# 2005-03-03 06:00:00     1160.0  74.1
# 2005-03-03 07:00:00     1217.0  75.6
# 2005-03-03 08:00:00     1457.0  72.4
# 2005-03-03 09:00:00     1337.0  50.2
# 2005-03-03 10:00:00     1111.0  39.4
# 2005-03-03 11:00:00     1165.0  75.9
# 2005-03-03 12:00:00     1129.0  78.6
# 2005-03-03 13:00:00     1092.0  69.2
# 2005-03-03 14:00:00     1096.0  66.0
# 2005-03-03 15:00:00     1108.0  70.1
# 2005-03-03 16:00:00     1124.0  72.1
# 2005-03-03 17:00:00     1216.0  75.7
# 2005-03-03 18:00:00     1437.0  80.4
# 2005-03-03 19:00:00     1473.0  82.4
# 2005-03-03 20:00:00     1396.0  84.0
# 2005-03-03 21:00:00     1285.0  83.6
# 2005-03-03 22:00:00     1206.0  82.5
# 2005-03-03 23:00:00     1179.0  82.0
# 2005-03-04 00:00:00        0.0   0.0

# %%
prediction=lasso.predict(pipe.transform(input_data))[0]

# %%
#Add the prediction to the horizon and the input data
f_horizon.loc[forcast_point]=prediction
input_data.loc[forcast_point] = prediction
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_5912\1038257637.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   input_data.loc[forcast_point] = prediction

# %%
# iteration it through the loop
for i in range(23):
    start_point = start_point + pd.offsets.Hour(1)
    forcast_point = forcast_point + pd.offsets.Hour(1)
    
    input_data = input_data[(input_data.index >= start_point)]
    input_data.loc[forcast_point] = 0
    
    prediction = lasso.predict(pipe.transform(input_data))
    
     # Add prediction to horizon.
    f_horizon.loc[forcast_point] = prediction
    input_data.loc[forcast_point] = prediction

f_horizon
# Out:
#                        CO_sensor         RH
# 2005-03-04 00:00:00  1208.076165  77.604145
# 2005-03-04 01:00:00  1211.440412  73.058271
# 2005-03-04 02:00:00  1196.721269  68.906272
# 2005-03-04 03:00:00  1174.858442  65.266229
# 2005-03-04 04:00:00  1156.187547  61.966888
# 2005-03-04 05:00:00  1137.036933  58.959372
# 2005-03-04 06:00:00  1121.620697  56.149365
# 2005-03-04 07:00:00  1109.627052  53.467022
# 2005-03-04 08:00:00  1109.605995  50.742802
# 2005-03-04 09:00:00  1101.378621  47.967233
# 2005-03-04 10:00:00  1081.013708  45.423857
# 2005-03-04 11:00:00  1058.015384  43.460628
# 2005-03-04 12:00:00  1040.173929  41.707722
# 2005-03-04 13:00:00  1028.846384  39.957426
# 2005-03-04 14:00:00   1020.94468  38.219857
# 2005-03-04 15:00:00  1012.738274  36.579032
# 2005-03-04 16:00:00  1004.997247  35.040907
# 2005-03-04 17:00:00  1000.971608  33.575129
# 2005-03-04 18:00:00  1004.817112   32.08751
# 2005-03-04 19:00:00  1003.399514  30.630316
# 2005-03-04 20:00:00   993.990978  29.339742
# 2005-03-04 21:00:00   980.391613  28.263122
# 2005-03-04 22:00:00   967.902244  27.338412
# 2005-03-04 23:00:00   959.275681   26.48118
